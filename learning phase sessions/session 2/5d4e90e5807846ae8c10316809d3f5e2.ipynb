# %% [markdown]
# In \[ \]:
#
#     import cv2
#     import numpy as np
#     from google.colab.patches import cv2_imshow
#
# ![image.png](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/a4c3ab18b2ef0a0b24460883a7ec0d1e36942d04.png)
#
# In \[ \]:
#
#     img = cv2.imread('download5.png')
#
# In \[ \]:
#
#     cv2_imshow(img)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/f974825624932fd2acff86b6f3064ec2e59620c8.png)
#
# In \[ \]:
#
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#
# In \[ \]:
#
#     cv2_imshow(gray)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/d72247a3e45104e7445e4a9b348ccb4947e5531a.png)
#
# In \[ \]:
#
#     ret, thresh1 = cv2.threshold(gray, 170, 255, cv2.THRESH_BINARY)
#
# In \[ \]:
#
#     cv2_imshow(thresh1)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/a4e227f44505c1baa4da9cc704ce9976e29acab5.png)
#
# In \[ \]:
#
#     print(thresh1)
#
#     [[255 255 255 ... 255 255 255]
#      [255 255 255 ... 255 255 255]
#      [255 255 255 ... 255 255 255]
#      ...
#      [255 255 255 ... 255 255 255]
#      [255 255 255 ... 255 255 255]
#      [255 255 255 ... 255 255 255]]
#
# In \[ \]:
#
#     ret, thresh2 = cv2.threshold(gray, 120, 255, cv2.THRESH_BINARY_INV)
#
# In \[ \]:
#
#     cv2_imshow(thresh2)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/70d040b9749e0b6ae2dcdaa74c75c30e447258db.png)
#
# In \[ \]:
#
#     ret, thresh3 = cv2.threshold(gray, 120, 255, cv2.THRESH_TRUNC)
#
# In \[ \]:
#
#     cv2_imshow(thresh3)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/94b090d6e6f3743bcc5a8c7272d10e5f0efe781f.png)
#
# In \[ \]:
#
#     cv2_imshow(gray)
#
# ![](attachment:vertopal_5d4e90e5807846ae8c10316809d3f5e2/d72247a3e45104e7445e4a9b348ccb4947e5531a.png)
#
# In \[ \]:

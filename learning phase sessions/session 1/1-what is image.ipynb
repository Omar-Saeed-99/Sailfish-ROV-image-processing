# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np 
import matplotlib.pylab as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# Create a random array with dimensions 500 x 500 x 3 and values ​​between 0 and 255
# **bold text**

# %%
rand_array = np.random.randint(0,255,(500,500,3))

# %%
print(rand_array)
# Out:
# [[[111 183 239]
#   [198 216 247]
#   [ 14 180  90]
#   ...
#   [ 77 149 250]
#   [139 173 155]
#   [172  93 214]]
#
#  [[222 218   7]
#   [ 82  77 178]
#   [116 124 201]
#   ...
#   [214 189  93]
#   [230  83  89]
#   [ 16 143 189]]
#
#  [[150 120 163]
#   [ 40  39 170]
#   [187 116 231]
#   ...
#   [228  64 147]
#   [254 106 170]
#   [178 233 155]]
#
#  ...
#
#  [[ 21 170 208]
#   [ 12  72 200]
#   [134  64 125]
#   ...
#   [ 65  82 114]
#   [229 232 138]
#   [ 22 161  86]]
#
#  [[222  28 223]
#   [210  90  91]
#   [163 120 237]
#   ...
#   [ 82 155 170]
#   [ 61 154 149]
#   [ 69   7 220]]
#
#  [[235 222 207]
#   [ 59 148 200]
#   [102 190 120]
#   ...
#   [ 92 250  60]
#   [ 83 101  57]
#   [205 174  39]]]

# %% [markdown]
# cv2_imshow A command used to display images, and from the image, it becomes clear that the image is an array with dimensions weight x higet x 3 and within it values ​​from 0 to 255 and the number 3 expresses RGB values

# %%
cv2_imshow(rand_array)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F368E8A6790>

# %% [markdown]
# When the number 3 is removed from the dimensions of the matrix, the result is a gray image
# The gray image is an image that has only two dimensions, length and width, and the values ​​range from 0 to 255. The 0 represents black and 255 represents white, and gray is between them.

# %%
rand_array = np.random.randint(0,255,(200,200))
cv2_imshow(rand_array)
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F368E845410>

# %%
black = np.zeros((500,500,3))

# %%
cv2_imshow(black)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F24E0FE35D0>

# %%
white = np.ones((500,500))*255

# %%
cv2_imshow(white)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F24E0FDDA90>
